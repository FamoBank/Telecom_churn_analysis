# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import OneHotEncoder
import plotly.express as px

# %%
telecom_df=pd.read_csv("./Dataset/WA_Fn-UseC_-Telco-Customer-Churn.csv")

# %%
telecom_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
telecom_df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
telecom_df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
telecom_df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# ...

# %%
telecom_df.iloc[6]
# Out:
# customerID                       1452-KIOVK
# gender                                 Male
# SeniorCitizen                             0
# Partner                                  No
# Dependents                              Yes
# tenure                                   22
# PhoneService                            Yes
# MultipleLines                           Yes
# InternetService                 Fiber optic
# OnlineSecurity                           No
# OnlineBackup                            Yes
# DeviceProtection                         No
# TechSupport                              No
# StreamingTV                             Yes
# StreamingMovies                          No
# Contract                     Month-to-month
# PaperlessBilling                        Yes
# PaymentMethod       Credit card (automatic)
# MonthlyCharges                         89.1
# TotalCharges                         1949.4
# Churn                                    No
# Name: 6, dtype: object

# %%
telecom_df.iloc[1:4]
# Out:
#    customerID gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 1  5575-GNVDE   Male              0      No         No      34          Yes
# 2  3668-QPYBK   Male              0      No         No       2          Yes
# 3  7795-CFOCW   Male              0      No         No      45           No
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
#
# ...

# %%
telecom_df.isnull()
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0          False   False          False    False       False   False
# 1          False   False          False    False       False   False
# 2          False   False          False    False       False   False
# 3          False   False          False    False       False   False
# 4          False   False          False    False       False   False
# ...          ...     ...            ...      ...         ...     ...
# 7038       False   False          False    False       False   False
# 7039       False   False          False    False       False   False
# 7040       False   False          False    False       False   False
# 7041       False   False          False    False       False   False
# 7042       False   False          False    False       False   False
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
telecom_df.rename(columns={"tenure":"Tenure"}).head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  Tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
def check_category(df):
    return pd.Series({c: df.select_dtypes("object")[c].unique() for c in df.select_dtypes("object")})

# %%
telecom_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# ...

# %%
check_category(telecom_df)
# Out:
# customerID          [7590-VHVEG, 5575-GNVDE, 3668-QPYBK, 7795-CFOC...
# gender                                                 [Female, Male]
# Partner                                                     [Yes, No]
# Dependents                                                  [No, Yes]
# PhoneService                                                [No, Yes]
# MultipleLines                             [No phone service, No, Yes]
# InternetService                                [DSL, Fiber optic, No]
# OnlineSecurity                         [No, Yes, No internet service]
# OnlineBackup                           [Yes, No, No internet service]
# DeviceProtection                       [No, Yes, No internet service]
# TechSupport                            [No, Yes, No internet service]
# StreamingTV                            [No, Yes, No internet service]
# StreamingMovies                        [No, Yes, No internet service]
# ...

# %%
from sklearn.preprocessing import LabelBinarizer

# %%
l_encode=LabelBinarizer()

# %%
l_encode=LabelBinarizer()

# %%
telecom_df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# ...          ...     ...            ...     ...        ...     ...
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0              No  No phone service             DSL             No  ...
# ...

# %%
telecom_df1 = telecom_df.copy()

# %%
telecom_df1.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df=pd.DataFrame(l_encode.fit_transform(telecom_df1.gender))

# %%
encoder_df=pd.DataFrame(l_encode.fit_transform(telecom_df1.gender))

# %%
final_df=telecom_df1.join(encoder_df)

# %%
final_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... TechSupport  \
# 0  No phone service             DSL             No  ...          No
# 1                No             DSL            Yes  ...          No
# 2                No             DSL            Yes  ...          No
# 3  No phone service             DSL            Yes  ...         Yes
# 4                No     Fiber optic             No  ...          No
#
#   StreamingTV StreamingMovies        Contract PaperlessBilling  \
# ...

# %%
#step:1 perform unique operation
telecom_df1["gender"].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
#step:2 create a mapper
telecom_df1_map={"Female":0,"Male":1,}

# %%
telecom_df1_map
# Out:
# {'Female': 0, 'Male': 1}

# %%
telecom_df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
# customerID          7043 non-null object
# gender              7043 non-null object
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null object
# Dependents          7043 non-null object
# tenure              7043 non-null int64
# PhoneService        7043 non-null object
# MultipleLines       7043 non-null object
# InternetService     7043 non-null object
# OnlineSecurity      7043 non-null object
# OnlineBackup        7043 non-null object
# DeviceProtection    7043 non-null object
# TechSupport         7043 non-null object
# StreamingTV         7043 non-null object
# StreamingMovies     7043 non-null object
# Contract            7043 non-null object
# PaperlessBilling    7043 non-null object
# PaymentMethod       7043 non-null object
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null object
# ...

# %%
#step:3 attached the mapping to dataframe
telecom_df1["gender"].replace(telecom_df1_map)
# Out:
# 0       0
# 1       1
# 2       1
# 3       1
# 4       0
#        ..
# 7038    1
# 7039    0
# 7040    0
# 7041    1
# 7042    1
# Name: gender, Length: 7043, dtype: int64

# %%
telecom_df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
#check for missing value.
telecom_df1.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#mapping multiple columns
map_cols = {
    "gender": {"Female":0,"Male":1},
    "Partner": {"Yes":1,"No":0},
    "Dependents":{"Yes":1,"No":0},
    "PhoneService": {"No phone service":0, "No":1, "Yes":2}
}

# %%
telecom_df1.replace(map_cols,inplace=True)

# %%
telecom_df1.head()
# Out:
#    customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0  7590-VHVEG       0              0        1           0       1
# 1  5575-GNVDE       1              0        0           0      34
# 2  3668-QPYBK       1              0        0           0       2
# 3  7795-CFOCW       1              0        0           0      45
# 4  9237-HQITU       0              0        0           0       2
#
#    PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 0             1  No phone service             DSL             No  ...
# 1             2                No             DSL            Yes  ...
# 2             2                No             DSL            Yes  ...
# 3             1  No phone service             DSL            Yes  ...
# 4             2                No     Fiber optic             No  ...
#
#   DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %% [markdown]
# # Visualization using Plotly Express

# %% [markdown]
# # visualization of OnlineBackup

# %%
OnlineBackup = telecom_df.groupby(["OnlineBackup"])["OnlineBackup"].count().reset_index(name="count")

# %%
px.bar(OnlineBackup, x="OnlineBackup", y="count", color="OnlineBackup", text_auto=True)
# Out:
# <div>                            <div id="19874c4d-c8ac-46a2-8ac6-803bd8ccf443" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("19874c4d-c8ac-46a2-8ac6-803bd8ccf443")) {                    Plotly.newPlot(                        "19874c4d-c8ac-46a2-8ac6-803bd8ccf443",                        [{"alignmentgroup":"True","hovertemplate":"OnlineBackup=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["No"],"xaxis":"x","y":[3088],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"OnlineBackup=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No internet service","marker":
# ...

# %% [markdown]
# # visualization of DeviceProtection

# %%
DeviceProtection = telecom_df.groupby(["DeviceProtection"])["DeviceProtection"].count().reset_index(name="count")

# %%
px.bar(DeviceProtection, x="DeviceProtection", y="count", color="DeviceProtection", text_auto=True)
# Out:
# <div>                            <div id="940ae346-dc8f-47c1-8299-8a40006893c6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("940ae346-dc8f-47c1-8299-8a40006893c6")) {                    Plotly.newPlot(                        "940ae346-dc8f-47c1-8299-8a40006893c6",                        [{"alignmentgroup":"True","hovertemplate":"DeviceProtection=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["No"],"xaxis":"x","y":[3095],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"DeviceProtection=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No internet service","
# ...

# %% [markdown]
# # visualization of TechSupport

# %%
TechSupport = telecom_df.groupby(["TechSupport"])["TechSupport"].count().reset_index(name="count")

# %%
px.pie(telecom_df, "TechSupport", hole=0.7)
# Out:
# <div>                            <div id="a21b6a34-39c7-475a-9e3d-d897e08c6f65" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a21b6a34-39c7-475a-9e3d-d897e08c6f65")) {                    Plotly.newPlot(                        "a21b6a34-39c7-475a-9e3d-d897e08c6f65",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.7,"hovertemplate":"TechSupport=%{label}<extra></extra>","labels":["No","No","No","Yes","No","No","No","No","Yes","No","No","No internet service","No","No","Yes","Yes","No internet service","No","Yes","No","No","No internet service","No internet service","Yes","Yes","No","No","No","Yes","No","Yes","No","Yes","No internet service","No","Yes","No","No","No","No","No","No","No internet service","Yes","Yes","No","No","N
# ...

# %% [markdown]
# # visualization of StreamingTV

# %%
StreamingTV = telecom_df.groupby(["StreamingTV"])["StreamingTV"].count().reset_index(name="count")

# %%
px.pie(telecom_df, "StreamingTV", hole=0.4)
# Out:
# <div>                            <div id="b928b7b1-b4e7-4bf4-9e63-fdcee2c42232" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b928b7b1-b4e7-4bf4-9e63-fdcee2c42232")) {                    Plotly.newPlot(                        "b928b7b1-b4e7-4bf4-9e63-fdcee2c42232",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"StreamingTV=%{label}<extra></extra>","labels":["No","No","No","No","No","Yes","Yes","No","Yes","No","No","No internet service","Yes","Yes","Yes","Yes","No internet service","Yes","No","No","No","No internet service","No internet service","No","No","No","Yes","No","Yes","Yes","No","Yes","No","No internet service","No","Yes","No","No","Yes","Yes","No","Yes","No internet service","Yes","Yes","No","N
# ...

# %% [markdown]
# # visualization of StreamingMovies

# %%
StreamingMovies = telecom_df.groupby(["StreamingMovies"])["StreamingMovies"].count().reset_index(name="count")

# %%
px.bar(StreamingMovies, x="StreamingMovies", y="count", color="StreamingMovies", text_auto=True)
# Out:
# <div>                            <div id="60f80e8e-c446-4304-b6d6-f4ec90c56905" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("60f80e8e-c446-4304-b6d6-f4ec90c56905")) {                    Plotly.newPlot(                        "60f80e8e-c446-4304-b6d6-f4ec90c56905",                        [{"alignmentgroup":"True","hovertemplate":"StreamingMovies=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","texttemplate":"%{y}","x":["No"],"xaxis":"x","y":[2785],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"StreamingMovies=%{x}<br>count=%{y}<extra></extra>","legendgroup":"No internet service","ma
# ...
